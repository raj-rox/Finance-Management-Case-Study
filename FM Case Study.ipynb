# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model as model
import numpy as np

# %%
data = pd.read_excel('./data.xlsx')

# %%
data.head(10)
# Out:
#       year  electricity  tyres_and_tubes  motor_vehicle  cycle_parts    WPI  \
# 0  2001-02        158.1            154.8          177.3        141.3  173.0
# 1  2002-03        171.6            155.1          173.4        143.6  176.6
# 2  2003-04        182.5            153.7          177.4        146.0  185.8
# 3  2004-05        209.1            181.5          193.2        157.6  185.8
# 4  2005-06        225.6            215.9          240.3        182.4  217.6
# 5  2006-07        239.7            252.1          278.1        193.7  256.9
# 6  2007-08        279.6            291.0          316.5        213.4  281.3
# 7  2008-09        328.2            315.5          326.8        226.1  288.7
# 8  2009-10        387.7            325.2          323.3        234.9  316.0
# 9  2010-11        414.1            344.5          339.0        252.8  338.3
#
#      CPI
# 0  313.0
# 1  301.0
# 2  324.0
# 3  331.0
# 4  360.0
# 5  401.0
# 6  451.0
# 7  486.0
# 8  547.0
# 9  582.0

# %%
data.electricity
# Out:
# 0    158.1
# 1    171.6
# 2    182.5
# 3    209.1
# 4    225.6
# 5    239.7
# 6    279.6
# 7    328.2
# 8    387.7
# 9    414.1
# Name: electricity, dtype: float64

# %%
lr = model.LinearRegression()

# %%
X = data.index.values.reshape(-1,1)
y = data.iloc[:,1].values.reshape(-1,1)

lr.fit(X,y)

y_pred = lr.predict(x_pred)
print(y_pred)
# Out:
# [[418.64666667]
#  [447.56060606]
#  [476.47454545]
#  [505.38848485]
#  [534.30242424]]

# %%
x_axis = data.iloc[:,0].values
X = data.index.values.reshape(-1,1)
y = data.iloc[:,1].values.reshape(-1,1)

lr.fit(X,y)

y_pred = lr.predict(X)

plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
y_pos = np.arange(15)
plt.xticks(y_pos, x_axis, rotation=50, horizontalalignment='right', fontweight='bold')

plt.xlabel('Year')
plt.ylabel('Electricity')
plt.title('Year v/s Electricity')
plt.show()

# %%
x_axis = data.iloc[:,0].values
X = data.index.values.reshape(-1,1)
y = data.iloc[:,2].values.reshape(-1,1)

lr.fit(X,y)

y_pred = lr.predict(X)

plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
y_pos = np.arange(15)
plt.xticks(y_pos, x_axis, rotation=50, horizontalalignment='right', fontweight='bold')

plt.xlabel('Year')
plt.ylabel('Tyres & Tubes')
plt.title('Year v/s Tyres & Tubes')
plt.show()

# %%
x_axis = data.iloc[:,0].values
X = data.index.values.reshape(-1,1)
y = data.iloc[:,3].values.reshape(-1,1)

lr.fit(X,y)

y_pred = lr.predict(X)

plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
y_pos = np.arange(15)
plt.xticks(y_pos, x_axis, rotation=50, horizontalalignment='right', fontweight='bold')

plt.xlabel('Year')
plt.ylabel('Motor vehicles')
plt.title('Year v/s Motor vehicles')
plt.show()

# %%
x_axis = data.iloc[:,0].values
X = data.index.values.reshape(-1,1)
y = data.iloc[:,4].values.reshape(-1,1)

lr.fit(X,y)

y_pred = lr.predict(X)

plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
y_pos = np.arange(15)
plt.xticks(y_pos, x_axis, rotation=50, horizontalalignment='right', fontweight='bold')

plt.xlabel('Year')
plt.ylabel('Cycle parts')
plt.title('Year v/s Cycle parts')
plt.show()

# %%
x_axis = data.iloc[:,0].values
X = data.index.values.reshape(-1,1)
y = data.iloc[:,5].values.reshape(-1,1)

lr.fit(X,y)

y_pred = lr.predict(X)

plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
y_pos = np.arange(15)
plt.xticks(y_pos, x_axis, rotation=50, horizontalalignment='right', fontweight='bold')

plt.xlabel('Year')
plt.ylabel('WPI')
plt.title('Year v/s WPI')
plt.show()

# %%
x_axis = data.iloc[:,0].values
X = data.index.values.reshape(-1,1)
y = data.iloc[:,6].values.reshape(-1,1)

lr.fit(X,y)

y_pred = lr.predict(X)

plt.scatter(X,y)
plt.plot(X,y_pred,color='red')
y_pos = np.arange(15)
plt.xticks(y_pos, x_axis, rotation=50, horizontalalignment='right', fontweight='bold')

plt.xlabel('Year')
plt.ylabel('CPI')
plt.title('Year v/s CPI')
plt.show()
